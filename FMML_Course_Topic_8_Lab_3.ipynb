# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhithakarpuram/FMML-Module-5-Project/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 12:09:11--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   129MB/s    in 0.5s
#
# 2024-03-31 12:09:12 (129 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 26261  1609.05590v1  For applications in navigation and robotics, e...    cs
# 5445    1210.5196v1  We introduce a new family of matrix norms, the...  stat
# 7683   1802.08246v1  We study the bias of generic optimization meth...  stat
# 7635   1802.05846v1  Model selection on validation data is an essen...  stat
# 31136  1802.04723v1  Image demosaicing - one of the most important ...    cs
# ...             ...                                                ...   ...
# 31217  1802.07589v1  One of the biggest problems in deep learning i...    cs
# 5674   1604.07143v1  Given an ensemble of randomized regression tre...  stat
# 37542  1709.05601v1  Markov Brains are a class of evolvable artific...    cs
# 34933  1604.00462v1  In this paper, we discuss the outer-synchroniz...    cs
# 3735   1501.04413v1  In this paper, we present a statistical-mechan...  stat
#
#                                                    title  year  \
# 26261     Fast Single Shot Detection and Pose Estimation  2016
# 5445       Matrix reconstruction with the local max norm  2012
# 7683   Characterizing Implicit Bias in Terms of Optim...  2018
# 7635       Train on Validation: Squeezing the Data Lemon  2018
# 31136  Joint Demosaicing and Denoising with Perceptua...  2018
# ...                                                  ...   ...
# 31217     Deep Collaborative Weight-based Classification  2018
# 5674                               Neural Random Forests  2016
# 37542            Markov Brains: A Technical Introduction  2017
# 34933  Centralized and Decentralized Global Outer-syn...  2016
# 3735   Statistical-mechanical analysis of pre-trainin...  2015
#
#                                                 keywords
# 26261  [applications, navigation, estimating, importa...
# 5445   [introduce, generalizing, extensively, literat...
# 7683   [optimization, including, different, potential...
# 7635   [selection, validation, essential, validation,...
# 31136  [demosaicing, important, pipelines, addressed,...
# ...                                                  ...
# 31217  [difficulty, consistent, robustness, transferr...
# 5674   [randomized, regression, restructure, collecti...
# 37542  [evolvable, artificial, conventional, differen...
# 34933  [synchronization, asymmetrically, connected, r...
# 3735   [statistical, mechanical, elucidate, essential...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 26261    [applications, navigation, estimating, importa...
# 5445     [introduce, generalizing, extensively, literat...
# 7683     [optimization, including, different, potential...
# 7635     [selection, validation, essential, validation,...
# 31136    [demosaicing, important, pipelines, addressed,...
#                                ...
# 28763    [furniture, aesthetic, similarities, identical...
# 12601    [rectified, preferred, activation, artificial,...
# 21334    [developments, established, vulnerability, rei...
# 10324    [prediction, collections, connected, predictio...
# 19270    [reasoning, approximations, particularly, situ...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8805 words.
# Out of those 4551 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="872190c2-ffeb-4f3a-b6a4-b7aa0f16fe21" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("872190c2-ffeb-4f3a-b6a4-b7aa0f16fe21")) {                    Plotly.newPlot(                        "872190c2-ffeb-4f3a-b6a4-b7aa0f16fe21",                        [{"x":["processing","categorization","navigation","convolutional","important","estimation","estimated","intermediate","including","approaches","detecting","localization","architecture","significantly","estimating","approximate","applications","locations","detection","keypoints","resulting","literature","conservative","theoretical","guarantees","interpolate","simulated","interpolation","introduce","extensively","reconstruction","movielens","regularizers","generalizing","classification","separable","potential","optimizing","underdetermined","regression","hyperparameter","characterizing","independently","potentials","algorithms","characterized","different","optimization","considered","validation","controlled","overfitting","squeezing","demonstrate","continuous","practitioners","performance","significant","practical","essential","selection","effective","subjective","developed","discriminator","especially","extensive","functions","objective","demosaicing","perceptual","corruption","denoising","addressed","experimental","computational","fundamental","reconstructed","contributions","particularly","convincingly","comparable","reconstructing","tremendous","assurance","adversarial","pipelines","resolution","component","generative","exploiting","characterising","descriptor","information","representation","introduction","candidate","encodings","sequences","kinematic","discriminative","demonstrated","challenge","evaluating","detectors","recognition","breakthrough","application","decomposition","complexity","heuristic","criterion","accelerated","presented","algorithm","frequencies","mechanism","magnitude","increasing","technique","adaptation","liblinear","established","shrinking","specialized","algorithmic","implementation","improvement","dimensional","counterpart","intervals","illustrate","simulation","deviation","assumption","independent","assumptions","smoothing","conditional","furthermore","precision","distribution","corresponding","confidence","developing","procedure","covariance","inference","probability","competitors","population","individual","independence","iterative","observations","outperforms","experiments","benchmarks","improving","supervised","sentiment","embeddings","asymmetric","embedding","effectively","sacrificing","attractive","spatially","properties","benchmark","generalization","regularization","synthetic","flexibility","conducted","efficient","specifying","downsampled","orthogonal","comparison","denoisers","desirable","selecting","techniques","informative","described","successfully","initially","resultant","evolutionary","recognise","electroencephalograms","artefacts","motivated","contaminated","constrained","statistics","likelihood","fundamentally","conventional"],"y":[286,34,27,385,356,241,69,30,257,428,79,51,245,273,77,120,455,35,361,7,159,130,9,153,59,2,54,12,282,33,105,2,9,13,509,14,141,49,2,105,9,22,30,11,611,25,724,336,104,48,32,25,1,522,115,20,871,244,140,68,147,250,19,200,8,113,164,212,142,2,25,6,55,37,378,271,90,20,51,66,3,94,16,9,2,99,13,121,108,116,76,2,26,698,358,32,67,10,93,6,95,103,153,60,40,390,3,261,80,230,67,48,13,187,835,13,107,60,98,231,75,0,48,1,19,37,127,118,162,13,13,74,59,11,71,115,63,15,87,175,81,194,139,37,68,117,26,213,175,11,53,130,24,88,62,266,596,90,116,223,41,84,14,111,115,3,19,23,208,214,113,88,144,27,91,388,10,4,22,140,4,42,44,368,54,68,87,25,5,66,4,2,3,59,5,59,46,60,7,91],"type":"bar"},{"x":["processing","categorization","navigation" ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4551,), (4551, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.815

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Coefficients</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.4705882352941176);'>Relations</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Probabilistic</span> <span style='background-color:rgba(0, 255, 0, 0.7880794701986756);'>Reasoning</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.7575757575757576);'>Definitions</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>notations</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>historical</span> <span style='background-color:rgba(0, 255, 0, 0.5999999999999999);'>references</span> <span style=''>are</span> <span style=''>given</span> <span style=''>for</span> <span style=''>some</span> <span style='background-color:rgba(255, 0, 0, 0.47142857142857136);'>numerical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>coefficients</span> <span style=''>commonly</span> <span style=''>used</span> <span style=''>to</span> <span style=''>quantify</span> <span style='background-color:rgba(0, 255, 0, 0.4705882352941176);'>relations</span> <span style=''>among</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>collections</span> <span style=''>of</span> <span style=''>objects</span> <span style=''>for</span> <span style=''>the</span> <span style=''>purpose</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.5384615384615384);'>expressing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style='background-color:rgba(0, 255, 0, 0.4128787878787878);'>knowledge</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(0, 255, 0, 0.7880794701986756);'>reasoning</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Focus</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Attention</span> <span style=''>for</span> <span style=''>Linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Predictors</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>method</span> <span style=''>to</span> <span style=''>stop</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluation</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>process</span> <span style=''>when</span> <span style=''>the</span> <span style=''>result</span> <span style=''>of</span> <span style=''>the</span> <span style=''>full</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluation</span> <span style=''>is</span> <span style=''>obvious</span> <span style=''>This</span> <span style=''>trait</span> <span style=''>is</span> <span style=''>highly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>desirable</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>tasks</span> <span style=''>where</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictor</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluates</span> <span style=''>all</span> <span style=''>its</span> <span style=''>features</span> <span style=''>for</span> <span style=''>every</span> <span style=''>example</span> <span style=''>in</span> <span style=''>large</span> <span style=''>datasets</span> <span style=''>We</span> <span style=''>observe</span> <span style=''>that</span> <span style=''>some</span> <span style=''>examples</span> <span style=''>are</span> <span style=''>easier</span> <span style=''>to</span> <span style=''>classify</span> <span style=''>than</span> <span style=''>others</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>phenomenon</span> <span style=''>which</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>characterized</span> <span style=''>by</span> <span style=''>the</span> <span style=''>event</span> <span style=''>when</span> <span style=''>most</span> <span style=''>of</span> <span style=''>the</span> <span style=''>features</span> <span style=''>agree</span> <span style=''>on</span> <span style=''>the</span> <span style=''>class</span> <span style=''>of</span> <span style=''>an</span> <span style=''>example</span> <span style=''>By</span> <span style=''>stopping</span> <span style=''>the</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluation</span> <span style=''>when</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>encountering</span> <span style=''>an</span> <span style=''>easy</span> <span style=''>to</span> <span style=''>classify</span> <span style=''>example</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictor</span> <span style=''>can</span> <span style=''>achieve</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>substantial</span> <span style=''>gains</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computation</span> <span style=''>Our</span> <span style=''>method</span> <span style=''>provides</span> <span style=''>a</span> <span style=''>natural</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attention</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>mechanism</span> <span style=''>for</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictors</span> <span style=''>where</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>concentrates</span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Enhanced</span> <span style=''>Low</span> <span style=''>Rank</span> <span style=''>Matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Approximation</span> <br/><br/><span style=''>This</span> <span style=''>letter</span> <span style=''>proposes</span> <span style=''>to</span> <span style=''>estimate</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>matrices</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulating</span> <span style=''>a</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style=''>with</span> <span style=''>non</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularization</span> <span style=''>We</span> <span style=''>employ</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameterized</span> <span style=''>non</span> <span style=''>convex</span> <span style=''>penalty</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>to</span> <span style=''>estimate</span> <span style=''>the</span> <span style=''>non</span> <span style=''>zero</span> <span style=''>singular</span> <span style=''>values</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>accurately</span> <span style=''>than</span> <span style=''>the</span> <span style=''>nuclear</span> <span style=''>norm</span> <span style=''>A</span> <span style=''>closed</span> <span style=''>form</span> <span style=''>solution</span> <span style=''>for</span> <span style=''>the</span> <span style=''>global</span> <span style=''>optimum</span> <span style=''>of</span> <span style=''>the</span> <span style=''>proposed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style=''>function</span> <span style=''>(sum</span> <span style=''>of</span> <span style=''>data</span> <span style=''>fidelity</span> <span style=''>and</span> <span style=''>the</span> <span style=''>non</span> <span style=''>convex</span> <span style=''>regularizer)</span> <span style=''>is</span> <span style=''>also</span> <span style=''>derived</span> <span style=''>The</span> <span style=''>solution</span> <span style=''>reduces</span> <span style=''>to</span> <span style=''>singular</span> <span style=''>value</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>thresholding</span> <span style=''>method</span> <span style=''>as</span> <span style=''>a</span> <span style=''>special</span> <span style=''>case</span> <span style=''>The</span> <span style=''>proposed</span> <span style=''>method</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrated</span> <span style=''>for</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>denoising</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Gradual</span> <span style=''>Learning</span> <span style=''>of</span> <span style=''>Deep</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Recurrent</span> <span style=''>Neural</span> <span style=''>Networks</span> <br/><br/><span style=''>Deep</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Recurrent</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>(RNNs)</span> <span style=''>achieve</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>results</span> <span style=''>in</span> <span style=''>many</span> <span style=''>sequence</span> <span style=''>to</span> <span style=''>sequence</span> <span style=''>tasks</span> <span style=''>However</span> <span style=''>deep</span> <span style=''>RNNs</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style=''>to</span> <span style=''>train</span> <span style=''>and</span> <span style=''>suffer</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>overfitting</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>training</span> <span style=''>method</span> <span style=''>that</span> <span style=''>trains</span> <span style=''>the</span> <span style=''>network</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>gradually</span> <span style=''>and</span> <span style=''>treats</span> <span style=''>each</span> <span style=''>layer</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individually</span> <span style=''>to</span> <span style=''>achieve</span> <span style=''>improved</span> <span style=''>results</span> <span style=''>in</span> <span style=''>language</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>modelling</span> <span style=''>tasks</span> <span style=''>Training</span> <span style=''>deep</span> <span style=''>LSTM</span> <span style=''>with</span> <span style=''>Gradual</span> <span style=''>Learning</span> <span style=''>(GL)</span> <span style=''>obtains</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>perplexity</span> <span style=''>of</span> <span style=''>617</span> <span style=''>on</span> <span style=''>the</span> <span style=''>Penn</span> <span style=''>Treebank</span> <span style=''>(PTB)</span> <span style=''>corpus</span> <span style=''>As</span> <span style=''>far</span> <span style=''>as</span> <span style=''>we</span> <span style=''>know</span> <span style=''>(as</span> <span style=''>for</span> <span style=''>the</span> <span style=''>20052017)</span> <span style=''>GL</span> <span style=''>improves</span> <span style=''>the</span> <span style=''>best</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>by</span> <span style=''>a</span> <span style=''>single</span> <span style=''>LSTMRHN</span> <span style=''>model</span> <span style=''>on</span> <span style=''>the</span> <span style=''>word</span> <span style=''>level</span> <span style=''>PTB</span> <span style=''>dataset</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10298883687432481)
# 	representation (0.12891609650702196)
# 	segmentation (0.06841915736406194)
# 	architecture (0.08822470291681671)
# 	knowledge (0.13431760893050054)
# 	information (0.25135037810586963)
# 	detection (0.1299963989917177)
# 	different (0.2607129996398992)
# 	convolutional (0.1386388188692834)
# 	recognition (0.14043932301044293)
#
# Some Statistics words are:
# 	variational (0.09688581314878893)
# 	estimation (0.17350469599604548)
# 	algorithm (0.393475037073653)
# 	variables (0.14434008897676717)
# 	statistical (0.15867523479980228)
# 	theoretical (0.16262975778546712)
# 	distribution (0.17894216510133465)
# 	inference (0.20761245674740483)
# 	dimensional (0.1903114186851211)
# 	regression (0.17202174987642116)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="70cb501b-4e4c-471d-911d-46e98871549e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("70cb501b-4e4c-471d-911d-46e98871549e")) {                    Plotly.newPlot(                        "70cb501b-4e4c-471d-911d-46e98871549e",                        [{"x":["processing","categorization","navigation","convolutional","important","estimation","estimated","intermediate","including","approaches","detecting","localization","architecture","significantly","estimating","approximate","applications","locations","detection","keypoints","resulting","literature","conservative","theoretical","guarantees","interpolate","simulated","interpolation","introduce","extensively","reconstruction","movielens","regularizers","generalizing","classification","separable","potential","optimizing","underdetermined","regression","hyperparameter","characterizing","independently","potentials","algorithms","characterized","different","optimization","considered","validation","controlled","overfitting","squeezing","demonstrate","continuous","practitioners","performance","significant","practical","essential","selection","effective","subjective","developed","discriminator","especially","extensive","functions","objective","demosaicing","perceptual","corruption","denoising","addressed","experimental","computational","fundamental","reconstructed","contributions","particularly","convincingly","comparable","reconstructing","tremendous","assurance","adversarial","pipelines","resolution","component","generative","exploiting","characterising","descriptor","information","representation","introduction","candidate","encodings","sequences","kinematic","discriminative","demonstrated","challenge","evaluating","detectors","recognition","breakthrough","application","decomposition","complexity","heuristic","criterion","accelerated","presented","algorithm","frequencies","mechanism","magnitude","increasing","technique","adaptation","liblinear","established","shrinking","specialized","algorithmic","implementation","improvement","dimensional","counterpart","intervals","illustrate","simulation","deviation","assumption","independent","assumptions","smoothing","conditional","furthermore","precision","distribution","corresponding","confidence","developing","procedure","covariance","inference","probability","competitors","population","individual","independence","iterative","observations","outperforms","experiments","benchmarks","improving","supervised","sentiment","embeddings","asymmetric","embedding","effectively","sacrificing","attractive","spatially","properties","benchmark","generalization","regularization","synthetic","flexibility","conducted","efficient","specifying","downsampled","orthogonal","comparison","denoisers","desirable","selecting","techniques","informative","described","successfully","initially","resultant","evolutionary","recognise","electroencephalograms","artefacts","motivated","contaminated","constrained","statistics","likelihood","fundamentally","conventional","computationally","theoretically","observation","identically","distributed","measurements","tightness","experimentally","parameters","superposition","modalities","particular","marketing","associated","tractable","understand","knowledge","analyzing","wikipedia","accessing","evolutions","statistical","mentioned","additional","characteristics","retrieval","evolution","representations","maximised","partitions","clustering","vectorial","geometric","relationship","dependence","multivariate","similarity","concerned","partitioning","statistic","dimensions","predictive","structures","reduction","competing","dimensionality","extension","influence","appropriate","divergence","decomposed","interested","laplacian","imba ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	liblinear
# 	factorizes
# 	nonconjugate
# 	uncollapsed
# 	ellipsoids
# 	binarized
# 	ferromagnetic
# 	resamples
# 	multiplayer
# 	majorizer
# 	visualise
# 	aerodynamic
# 	distribute
# 	inverting
# 	concordance
# 	censoring
# 	concordant
# 	standardizing
# 	temperatures
# 	physiologic
# Some words which never appear in Statistics papers:
# 	keypoints
# 	demosaicing
# 	characterising
# 	kinematic
# 	downsampled
# 	denoisers
# 	recognise
# 	electroencephalograms
# 	artefacts
# 	argumentation
# 	certainty
# 	acceptability
# 	vectorized
# 	programmatic
# 	ontological
# 	developer
# 	logarithmical
# 	diversities
# 	conversational
# 	programmer

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.093963676866434e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7658333333333334
